# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('2019.csv', encoding='latin1')
# Out:
# C:\Users\saive\AppData\Local\Temp\ipykernel_228\2050930110.py:1: DtypeWarning: Columns (13,32) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('2019.csv', encoding='latin1')

# %%
df.head()
# Out:
#    AsOfDate Program                        BorrName  \
# 0  20221231      7A             RIVERLAND LASER LLC
# 1  20221231      7A      MARTINEZ AND MARTINEZ INC.
# 2  20221231      7A  Erez & Koby Genesis Investment
# 3  20221231      7A               Square Burger LLC
# 4  20221231      7A                 HIT FITNESS LLC
#
#                      BorrStreet     BorrCity BorrState  BorrZip  \
# 0           703 ST CROIX STREET  RIVER FALLS        WI    54022
# 1                 2430 DALY AVE  LOS ANGELES        CA    90031
# 2  10999 Reed Hartman Hwy, SUit   CINCINNATI        OH    45242
# 3           115 Kentucky Street     McKinney        TX    75069
# 4       614 A SOUTH MAIN STREET      MAULDIN        SC    29662
#
#                                     BankName  BankFDICNumber  BankNCUANumber  \
# 0              First National Community Bank          5357.0             NaN
# 1                                   Gain FCU             NaN          3943.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 545751 entries, 0 to 545750
# Data columns (total 39 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   AsOfDate               545751 non-null  int64
#  1   Program                545751 non-null  object
#  2   BorrName               545717 non-null  object
#  3   BorrStreet             545751 non-null  object
#  4   BorrCity               545751 non-null  object
#  5   BorrState              545751 non-null  object
#  6   BorrZip                545751 non-null  int64
#  7   BankName               545751 non-null  object
#  8   BankFDICNumber         508115 non-null  float64
#  9   BankNCUANumber         16788 non-null   float64
#  10  BankStreet             545749 non-null  object
#  11  BankCity               545749 non-null  object
#  12  BankState              545749 non-null  object
#  13  BankZip                545749 non-null  object
# ...

# %%
df.describe()
# Out:
#          AsOfDate        BorrZip  BankFDICNumber  BankNCUANumber  \
# count    545751.0  545751.000000   508115.000000    16788.000000
# mean   20221231.0   52238.354072    17999.109424    43227.228318
# std           0.0   30830.456758    18511.155548    25769.789691
# min    20221231.0     601.000000       35.000000       28.000000
# 25%    20221231.0   27615.000000     3832.000000    24405.000000
# 50%    20221231.0   50325.000000     9846.000000    60793.000000
# 75%    20221231.0   80237.000000    27237.000000    67190.000000
# max    20221231.0   99929.000000    91280.000000    97069.000000
#
#        GrossApproval  SBAGuaranteedApproval  ApprovalFiscalYear  \
# count   5.457510e+05           5.457510e+05       545751.000000
# mean    3.773959e+05           2.796713e+05         2014.724823
# std     6.722855e+05           5.156727e+05            2.812685
# min     1.000000e+03           5.000000e+02         2010.000000
# ...

# %%
date_cols = ['AsOfDate', 'ApprovalDate', 'FirstDisbursementDate']
for col in date_cols:
      df[col] = pd.to_datetime(df[col], errors='coerce')

print(date_cols)
# Out:
# ['AsOfDate', 'ApprovalDate', 'FirstDisbursementDate']

# %%
df.head()
# Out:
#                        AsOfDate Program                        BorrName  \
# 0 1970-01-01 00:00:00.020221231      7A             RIVERLAND LASER LLC
# 1 1970-01-01 00:00:00.020221231      7A      MARTINEZ AND MARTINEZ INC.
# 2 1970-01-01 00:00:00.020221231      7A  Erez & Koby Genesis Investment
# 3 1970-01-01 00:00:00.020221231      7A               Square Burger LLC
# 4 1970-01-01 00:00:00.020221231      7A                 HIT FITNESS LLC
#
#                      BorrStreet     BorrCity BorrState  BorrZip  \
# 0           703 ST CROIX STREET  RIVER FALLS        WI    54022
# 1                 2430 DALY AVE  LOS ANGELES        CA    90031
# 2  10999 Reed Hartman Hwy, SUit   CINCINNATI        OH    45242
# 3           115 Kentucky Street     McKinney        TX    75069
# 4       614 A SOUTH MAIN STREET      MAULDIN        SC    29662
#
#                                     BankName  BankFDICNumber  BankNCUANumber  \
# ...

# %%
df.drop_duplicates(inplace=True)

# %%
df['InitialInterestRate'] = pd.to_numeric(df['InitialInterestRate'], errors='coerce')
df['TermInMonths'] = pd.to_numeric(df['TermInMonths'], errors='coerce')
df['GrossApproval'] = pd.to_numeric(df['GrossApproval'], errors='coerce')
df['SBAGuaranteedApproval'] = pd.to_numeric(df['SBAGuaranteedApproval'], errors='coerce')

# %%
df.fillna({'FranchiseName': 'Not a Franchise', 'LoanStatus': 'Unknown'}, inplace=True)

# %%
df['LoanStatus'] = df['LoanStatus'].str.lower().str.strip()

# %%
df.drop(columns=['BankFDICNumber', 'BankNCUANumber', 'CongressionalDistrict'], inplace=True, errors='ignore')

# %%
df.to_csv("cleaned_loan_data.csv", index=False)
print("Data cleaning done. Saved as 'cleaned_loan_data.csv'.")
# Out:
# Data cleaning done. Saved as 'cleaned_loan_data.csv'.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 544602 entries, 0 to 545750
# Data columns (total 36 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   AsOfDate               544602 non-null  datetime64[ns]
#  1   Program                544602 non-null  object
#  2   BorrName               544568 non-null  object
#  3   BorrStreet             544602 non-null  object
#  4   BorrCity               544602 non-null  object
#  5   BorrState              544602 non-null  object
#  6   BorrZip                544602 non-null  int64
#  7   BankName               544602 non-null  object
#  8   BankStreet             544600 non-null  object
#  9   BankCity               544600 non-null  object
#  10  BankState              544600 non-null  object
#  11  BankZip                544600 non-null  object
#  12  GrossApproval          544602 non-null  int64
#  13  SBAGuaranteedApproval  544602 non-null  float64
# ...
